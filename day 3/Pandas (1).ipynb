# %%
import pandas as pd
b = pd.array([1,2,3])
print(b)

import numpy as np
a = np.array([1,2,3,])
print(a)
# Out:
# <IntegerArray>
# [1, 2, 3]
# Length: 3, dtype: Int64
# [1 2 3]

# %%
from numpy.random import randn
np.random.seed(101)
a = np.random.randn(101)
a
# Out:
# array([ 2.70684984e+00,  6.28132709e-01,  9.07969446e-01,  5.03825754e-01,
#         6.51117948e-01, -3.19318045e-01, -8.48076983e-01,  6.05965349e-01,
#        -2.01816824e+00,  7.40122057e-01,  5.28813494e-01, -5.89000533e-01,
#         1.88695309e-01, -7.58872056e-01, -9.33237216e-01,  9.55056509e-01,
#         1.90794322e-01,  1.97875732e+00,  2.60596728e+00,  6.83508886e-01,
#         3.02665449e-01,  1.69372293e+00, -1.70608593e+00, -1.15911942e+00,
#        -1.34840721e-01,  3.90527843e-01,  1.66904636e-01,  1.84501859e-01,
#         8.07705914e-01,  7.29596753e-02,  6.38787013e-01,  3.29646299e-01,
#        -4.97104023e-01, -7.54069701e-01, -9.43406403e-01,  4.84751647e-01,
#        -1.16773316e-01,  1.90175480e+00,  2.38126959e-01,  1.99665229e+00,
#        -9.93263500e-01,  1.96799505e-01, -1.13664459e+00,  3.66479606e-04,
#         1.02598415e+00, -1.56597904e-01, -3.15791439e-02,  6.49825833e-01,
#         2.15484644e+00, -6.10258856e-01, -7.55325340e-01, -3.46418504e-01,
#         1.47026771e-01, -4.79448039e-01,  5.58769406e-01,  1.02481028e+00,
#        -9.25874259e-01,  1.86286414e+00, -1.13381716e+00,  6.10477908e-01,
#         3.86030312e-01,  2.08401853e+00, -3.76518675e-01,  2.30336344e-01,
#         6.81209293e-01,  1.03512507e+00, -3.11604815e-02,  1.93993231e+00,
#        -1.00518692e+00, -7.41789705e-01,  1.87124522e-01, -7.32845148e-01,
#        -1.38292010e+00,  1.48249550e+00,  9.61458156e-01, -2.14121229e+00,
#         9.92573453e-01,  1.19224064e+00, -1.04677954e+00,  1.29276458e+00,
#        -1.46751402e+00, -4.94095358e-01, -1.62534735e-01,  4.85808737e-01,
#         3.92488811e-01,  2.21490685e-01, -8.55196041e-01,  1.54199041e+00,
#         6.66319321e-01, -5.38234626e-01, -5.68581361e-01,  1.40733825e+00,
#         6.41805511e-01, -9.05099902e-01, -3.91156627e-01,  1.02829316e+00,
#        -1.97260510e+00, -8.66885035e-01,  7.20787599e-01, -1.22308204e+00,
#         1.60677986e+00])

# %%
df = pd.DataFrame(randn(10,4),columns='W X Y Z'.split())

# %%
df.head()
# Out:
#           W         X         Y         Z
# 0 -1.115710 -1.385379 -1.329660  0.041460
# 1 -0.411055 -0.771329  0.110477 -0.804652
# 2  0.253548  0.649148  0.358941 -1.080471
# 3  0.902398  0.161781  0.833029  0.975720
# 4 -0.388239  0.783316 -0.708954  0.586847

# %%
df.head(2)
# Out:
#           W         X         Y         Z
# 0 -1.115710 -1.385379 -1.329660  0.041460
# 1 -0.411055 -0.771329  0.110477 -0.804652

# %%
df.tail()
# Out:
#           W         X         Y         Z
# 5 -1.621348  0.677535  0.026105 -1.678284
# 6  0.333973 -0.532471  2.117727  0.197524
# 7  2.302987  0.729024 -0.863091  0.305632
# 8  0.243178  0.864165 -1.560931 -0.251897
# 9 -0.578120  0.236996  0.200780  0.327845

# %%
df.tail(2)
# Out:
#           W         X         Y         Z
# 8  0.243178  0.864165 -1.560931 -0.251897
# 9 -0.578120  0.236996  0.200780  0.327845

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.shape
# Out:
# (10, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       10 non-null     float64
#  1   X       10 non-null     float64
#  2   Y       10 non-null     float64
#  3   Z       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
df.describe()
# Out:
#                W          X          Y          Z
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.007839   0.141279  -0.081558  -0.138028
# std     1.099490   0.778373   1.092717   0.819383
# min    -1.621348  -1.385379  -1.560931  -1.678284
# 25%    -0.536354  -0.358908  -0.824557  -0.666463
# 50%    -0.072531   0.443072   0.068291   0.119492
# 75%     0.313867   0.716152   0.319401   0.322291
# max     2.302987   0.864165   2.117727   0.975720

# %%
df = pd.DataFrame(randn(10,4),index='A B C D E F G H I J'.split(),columns='W X Y Z'.split())
df.head()
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# B -0.409318  0.343539  0.196275 -0.982776
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290
# E -0.219311 -0.045676  0.012421  0.093628

# %% [markdown]
# ## Selection and Indexing

# %%
df['W']
# Out:
# A    0.674485
# B   -0.409318
# C    2.231555
# D    0.528187
# E   -0.219311
# F    1.240813
# G   -1.666059
# H   -0.626805
# I    0.897796
# J   -0.945588
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A  0.674485 -0.383258
# B -0.409318 -0.982776
# C  2.231555  1.133703
# D  0.528187 -1.398290
# E -0.219311  0.093628
# F  1.240813 -0.380104
# G -1.666059  0.178009
# H -0.626805  1.130018
# I  0.897796 -0.125381
# J -0.945588 -1.306482

# %%
type(df[['W', 'Z']])
# Out:
# pandas.core.frame.DataFrame

# %%
# SQL Syntax (NOT RECOMMENDED!)
df.W
# Out:
# A    0.674485
# B   -0.409318
# C    2.231555
# D    0.528187
# E   -0.219311
# F    1.240813
# G   -1.666059
# H   -0.626805
# I    0.897796
# J   -0.945588
# Name: W, dtype: float64

# %% [markdown]
# **Creating a new column:**

# %%
df['new'] = df['W'] + df['Y'] # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new
# A  0.674485 -0.174057  0.780140 -0.383258  1.454625
# B -0.409318  0.343539  0.196275 -0.982776 -0.213043
# C  2.231555 -0.971393 -1.522333  1.133703  0.709222
# D  0.528187  0.393461 -0.630507 -1.398290 -0.102320
# E -0.219311 -0.045676  0.012421  0.093628 -0.206890

# %%
df['new2'] = df['X']**2 + df['Y'] + df['W'] + df['X'] # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new      new2
# A  0.674485 -0.174057  0.780140 -0.383258  1.454625  1.310864
# B -0.409318  0.343539  0.196275 -0.982776 -0.213043  0.248515
# C  2.231555 -0.971393 -1.522333  1.133703  0.709222  0.681433
# D  0.528187  0.393461 -0.630507 -1.398290 -0.102320  0.445952
# E -0.219311 -0.045676  0.012421  0.093628 -0.206890 -0.250480

# %%
df['new3'] = 1 # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new      new2  new3
# A  0.674485 -0.174057  0.780140 -0.383258  1.454625  1.310864     1
# B -0.409318  0.343539  0.196275 -0.982776 -0.213043  0.248515     1
# C  2.231555 -0.971393 -1.522333  1.133703  0.709222  0.681433     1
# D  0.528187  0.393461 -0.630507 -1.398290 -0.102320  0.445952     1
# E -0.219311 -0.045676  0.012421  0.093628 -0.206890 -0.250480     1

# %%
df['new3'].unique()
# Out:
# array([1])

# %%
df['new3'].nunique()
# Out:
# 1

# %%
df['W'].max()
# Out:
# 2.231555243446201

# %%
df['W'].mean()
# Out:
# 0.170575418070064

# %%
df['W'].median()
# Out:
# 0.15443800917806366

# %% [markdown]
# ** Removing Columns**

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z      new2  new3
# A  0.674485 -0.174057  0.780140 -0.383258  1.310864     1
# B -0.409318  0.343539  0.196275 -0.982776  0.248515     1
# C  2.231555 -0.971393 -1.522333  1.133703  0.681433     1
# D  0.528187  0.393461 -0.630507 -1.398290  0.445952     1
# E -0.219311 -0.045676  0.012421  0.093628 -0.250480     1
# F  1.240813 -1.097693 -1.908009 -0.380104 -0.559959     1
# G -1.666059 -2.736995  1.522562  0.178009  4.610648     1
# H -0.626805 -0.391089  1.743477  1.130018  0.878533     1
# I  0.897796  0.330866 -1.063049 -0.125381  0.275085     1
# J -0.945588  2.029544 -1.046358 -1.306482  4.156647     1

# %%
df
# Out:
#           W         X         Y         Z       new      new2  new3
# A  0.674485 -0.174057  0.780140 -0.383258  1.454625  1.310864     1
# B -0.409318  0.343539  0.196275 -0.982776 -0.213043  0.248515     1
# C  2.231555 -0.971393 -1.522333  1.133703  0.709222  0.681433     1
# D  0.528187  0.393461 -0.630507 -1.398290 -0.102320  0.445952     1
# E -0.219311 -0.045676  0.012421  0.093628 -0.206890 -0.250480     1
# F  1.240813 -1.097693 -1.908009 -0.380104 -0.667196 -0.559959     1
# G -1.666059 -2.736995  1.522562  0.178009 -0.143497  4.610648     1
# H -0.626805 -0.391089  1.743477  1.130018  1.116672  0.878533     1
# I  0.897796  0.330866 -1.063049 -0.125381 -0.165253  0.275085     1
# J -0.945588  2.029544 -1.046358 -1.306482 -1.991947  4.156647     1

# %%
df = df.drop('new',axis=1) # Axis 0 means rows, axis 1 means columns
df
# Out:
#           W         X         Y         Z      new2  new3
# A  0.674485 -0.174057  0.780140 -0.383258  1.310864     1
# B -0.409318  0.343539  0.196275 -0.982776  0.248515     1
# C  2.231555 -0.971393 -1.522333  1.133703  0.681433     1
# D  0.528187  0.393461 -0.630507 -1.398290  0.445952     1
# E -0.219311 -0.045676  0.012421  0.093628 -0.250480     1
# F  1.240813 -1.097693 -1.908009 -0.380104 -0.559959     1
# G -1.666059 -2.736995  1.522562  0.178009  4.610648     1
# H -0.626805 -0.391089  1.743477  1.130018  0.878533     1
# I  0.897796  0.330866 -1.063049 -0.125381  0.275085     1
# J -0.945588  2.029544 -1.046358 -1.306482  4.156647     1

# %%
df = df.drop(['new2','new3'],axis=1)
df
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# B -0.409318  0.343539  0.196275 -0.982776
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290
# E -0.219311 -0.045676  0.012421  0.093628
# F  1.240813 -1.097693 -1.908009 -0.380104
# G -1.666059 -2.736995  1.522562  0.178009
# H -0.626805 -0.391089  1.743477  1.130018
# I  0.897796  0.330866 -1.063049 -0.125381
# J -0.945588  2.029544 -1.046358 -1.306482

# %% [markdown]
# Can also drop rows this way:

# %%
df = df.drop('E',axis=0)
df
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# B -0.409318  0.343539  0.196275 -0.982776
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290
# F  1.240813 -1.097693 -1.908009 -0.380104
# G -1.666059 -2.736995  1.522562  0.178009
# H -0.626805 -0.391089  1.743477  1.130018
# I  0.897796  0.330866 -1.063049 -0.125381
# J -0.945588  2.029544 -1.046358 -1.306482

# %%
df = df.drop(['F','G','H','I','J'],axis=0)
df
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# B -0.409318  0.343539  0.196275 -0.982776
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290

# %% [markdown]
# ** Selecting Rows**

# %%
df
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# B -0.409318  0.343539  0.196275 -0.982776
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290

# %%
df.loc['A']
# Out:
# W    0.674485
# X   -0.174057
# Y    0.780140
# Z   -0.383258
# Name: A, dtype: float64

# %%
df.loc[['A','B']]
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# B -0.409318  0.343539  0.196275 -0.982776

# %% [markdown]
# Or select based off of position instead of label

# %%
df.iloc[2]
# Out:
# W    2.231555
# X   -0.971393
# Y   -1.522333
# Z    1.133703
# Name: C, dtype: float64

# %%
df.iloc[2:5]
# Out:
#           W         X         Y         Z
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290

# %%
df.iloc[1::2]
# Out:
#           W         X         Y         Z
# B -0.409318  0.343539  0.196275 -0.982776
# D  0.528187  0.393461 -0.630507 -1.398290

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# B -0.409318  0.343539  0.196275 -0.982776
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290

# %%
df.loc['B','Y']
# Out:
# 0.1962753160993944

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  0.674485  0.780140
# B -0.409318  0.196275

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# B -0.409318  0.343539  0.196275 -0.982776
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290

# %%
df > 0
# Out:
#        W      X      Y      Z
# A   True  False   True  False
# B  False   True   True  False
# C   True  False  False   True
# D   True   True  False  False

# %%
df[df['W'] > 0]
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290

# %%
df[df['W'] > 0]['Y']
# Out:
# A    0.780140
# C   -1.522333
# D   -0.630507
# Name: Y, dtype: float64

# %%
df[df['W'] > 0][['Y','X']]
# Out:
#           Y         X
# A  0.780140 -0.174057
# C -1.522333 -0.971393
# D -0.630507  0.393461

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df
# Out:
#           W         X         Y         Z
# A  0.674485 -0.174057  0.780140 -0.383258
# B -0.409318  0.343539  0.196275 -0.982776
# C  2.231555 -0.971393 -1.522333  1.133703
# D  0.528187  0.393461 -0.630507 -1.398290

# %%
df[(df['W'] > 0) & (df['Y'] > 0)]
# Out:
#           W         X         Y        Z
# D  0.147027 -0.479448  0.558769  1.02481

# %%
df[(df['W'] > 0) | (df['Y'] > 1)]
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
# Reset to default 0,1...n index
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A -0.993263  0.196800 -1.136645  0.000366
# 1     B  1.025984 -0.156598 -0.031579  0.649826
# 2     C  2.154846 -0.610259 -0.755325 -0.346419
# 3     D  0.147027 -0.479448  0.558769  1.024810

# %%
newind = 'CA NY WY NY'.split()
newind
# Out:
# ['CA', 'NY', 'WY', 'NY']

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.993263  0.196800 -1.136645  0.000366     CA
# B  1.025984 -0.156598 -0.031579  0.649826     NY
# C  2.154846 -0.610259 -0.755325 -0.346419     WY
# D  0.147027 -0.479448  0.558769  1.024810     NY

# %%
df['States'].value_counts()
# Out:
# States
# NY    2
# CA    1
# WY    1
# Name: count, dtype: int64

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA     -0.993263  0.196800 -1.136645  0.000366
# NY      1.025984 -0.156598 -0.031579  0.649826
# WY      2.154846 -0.610259 -0.755325 -0.346419
# NY      0.147027 -0.479448  0.558769  1.024810

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.993263  0.196800 -1.136645  0.000366     CA
# B  1.025984 -0.156598 -0.031579  0.649826     NY
# C  2.154846 -0.610259 -0.755325 -0.346419     WY
# D  0.147027 -0.479448  0.558769  1.024810     NY

# %% [markdown]
# # Missing Data
#
# Let's show a few convenient methods to deal with Missing Data in pandas:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
df.isna().mean()
# Out:
# A    0.333333
# B    0.666667
# C    0.000000
# dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# # Groupby
#
# The groupby method allows you to group rows of data together and call aggregate functions

# %%
import pandas as pd
# Our data: dictionary of lists
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ** Now you can use the .groupby() method to group rows together based off of a column name. For instance let's group based off of Company. This will create a DataFrameGroupBy object:**

# %%
df.groupby('Company')

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
by_comp = df.groupby("Company")['Sales'].mean()

print(by_comp)
# Out:
# Company
# FB      296.5
# GOOG    160.0
# MSFT    232.0
# Name: Sales, dtype: float64

# %%
by_comp = df.groupby("Company")['Sales'].sum()

print(by_comp)
# Out:
# Company
# FB      593
# GOOG    320
# MSFT    464
# Name: Sales, dtype: int64

# %%
by_comp = df.groupby("Company")['Sales'].max()

print(by_comp)
# Out:
# Company
# FB      350
# GOOG    200
# MSFT    340
# Name: Sales, dtype: int64

# %%
by_comp = df.groupby("Company")['Sales'].min()

print(by_comp)
# Out:
# Company
# FB      243
# GOOG    120
# MSFT    124
# Name: Sales, dtype: int64

# %% [markdown]
# ### Example DataFrames

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ## Concatenation

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

df2 = pd.DataFrame({
    'C': ['a', 'b', 'c'],
    'D': ['x', 'y', 'z']
})

# %%
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df2
# Out:
#    C  D
# 0  a  x
# 1  b  y
# 2  c  z

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    A  B  C  D
# 0  1  4  a  x
# 1  2  5  b  y
# 2  3  6  c  z

# %% [markdown]
# # Operations

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ### Applying Functions

# %%
def times2(x):
    return x*2

df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col1'].apply(lambda x:x*2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %% [markdown]
# ** Sorting and Ordering a DataFrame:**

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
data = {
    'col1': [3, 1, 2, 3, 2],
    'col2': [5, 4, 3, 2, 1],
    'col3': ['A', 'B', 'C', 'D', 'E']
}

df = pd.DataFrame(data)
df
# Out:
#    col1  col2 col3
# 0     3     5    A
# 1     1     4    B
# 2     2     3    C
# 3     3     2    D
# 4     2     1    E

# %%
df.sort_values(by='col2')
# Out:
#    col1  col2 col3
# 4     2     1    E
# 3     3     2    D
# 2     2     3    C
# 1     1     4    B
# 0     3     5    A

# %%
df.sort_values(by='col2',ascending=False)
# Out:
#    col1  col2 col3
# 0     3     5    A
# 1     1     4    B
# 2     2     3    C
# 3     3     2    D
# 4     2     1    E

# %% [markdown]
# # read and write to files

# %%
import pandas as pd

# Step 1: Create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)

df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
csv_file = 'sample_data.csv'
df.to_csv(csv_file, index=False)

# %%
read_df = pd.read_excel('/content/Titanic-Dataset (1).xlsx')
read_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#pd.read_excel csv (comma seperated file)
#pd.read_excel .xlsx
#pd.read_html .html
